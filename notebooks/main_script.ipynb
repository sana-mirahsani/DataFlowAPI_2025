# %% [markdown]
# # Main script to run all process.

# %% [markdown]
# ## 1.Library

# %%
import sys
import os
import pandas as pd

# Add the src folder to the Python path
sys.path.append(os.path.abspath("../src"))

# Import modules:
from data_utils import load_data, save_data, explore_data, clean_data, rescale_data, drop_columns, encode_categorical, split_data

# %% [markdown]
# ## 2.Data Preprocessing

# %%
# load and explore data
data_path = os.path.abspath("../data/train.csv")

df = load_data(data_path) 
explore_data(df)
# Out:
# Shape: (60000, 6)
# Head:
#     ID                                     review_content  \
# 0   0  En appelant un acheteur pour demander si l'écr...
# 1   1  Alors, là, on a affaire au plus grand Navet ja...
# 2   2  Effet garanti sur la terrase. Ils donnent immé...
# 3   3  tres bon rapport qualite prix tre pratique en ...
# 4   4  Ordinateur de bureau trés bien pour quelqu'un ...
#
#                                         review_title  review_stars  \
# 0  La Police s'inscrit en acheteur privé sur Pric...             5
# 1                     Chef D'Oeuvre Absolu en vue...             5
# 2  Effet garanti sur la terrase. Ils donnent immé...             3
# 3                                        bon produit             4
# 4                                 Apple Power MAC G4             3
#
#                                              product  Target
# 0  2fbb619e3606f9b7c213e858a109cda771aa2c47ce50d5...       0
# 1  7b56d9d378d9e999d293f301ac43d044cd7b4786d09afb...       1
# ...

# %%
# Clean data : remove duplicates and Nall values
df_clean = clean_data(df)
df_clean.shape
# Out:
# No duplicate rows found.
# Found 3 missing values. Filling them with 0...
# After filling missing values: 0 missing values remaining
# (60000, 6)

# %%
# Encode the categorical columns
# Select categorical columns
cat_cols = df_clean.select_dtypes(include=["object", "category"]).columns.tolist()
print("Categorical columns are : ")
print(cat_cols)

df_clean = encode_categorical(df_clean, cat_cols)

# Check if there is any
cat_cols = df_clean.select_dtypes(include=["object", "category"]).columns.tolist()
if len(cat_cols) > 0 :
    print("There are still categorical columns!")
else:
    print("Categorical columns are encoded successfuly!")
# Out:
# Categorical columns are :
# ['review_content', 'review_title', 'product']
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 7
#       4 print("Categorical columns are : ")
#       5 print(cat_cols)
# ----> 7 df_clean = encode_categorical(df_clean, cat_cols)
#       9 # Check if there is any
#      10 cat_cols = df_clean.select_dtypes(include=["object", "category"]).columns.tolist()
#
# File d:\my-github\DataFlowAPI_2025\src\data_utils.py:151, in encode_categorical(df, columns)
#     139 def encode_categorical(df: pd.DataFrame, columns: list[str]) -> pd.DataFrame:
#     140     """Convert categorical columns to numeric using one-hot encoding.
#     141
#     142     Args:
#    (...)
#     149         A dataframe with numeric columns.
#     150     """
# --> 151     return pd.get_dummies(df, columns=columns, drop_first=True)
#
# ...
