# %% [markdown]
# # Main script to run all process.

# %% [markdown]
# ## 1. Library

# %%
import sys
import os
import pandas as pd

# Add the src folder to the Python path
sys.path.append(os.path.abspath("../src"))

# Import modules:
from data_utils import load_data, save_data, explore_data, clean_data, create_text_column, clean_text, convert_by_TF_IDF, split_data
from model_utils import logistic_regression_model_training, eval_lr_model

# %% [markdown]
# ## 2. Data Preprocessing

# %%
# load and explore data
data_path = os.path.abspath("../data/train.csv")

df = load_data(data_path) 
explore_data(df)
# Out:
# Shape: (60000, 6)
# Head:
#     ID                                     review_content  \
# 0   0  En appelant un acheteur pour demander si l'écr...
# 1   1  Alors, là, on a affaire au plus grand Navet ja...
# 2   2  Effet garanti sur la terrase. Ils donnent immé...
# 3   3  tres bon rapport qualite prix tre pratique en ...
# 4   4  Ordinateur de bureau trés bien pour quelqu'un ...
#
#                                         review_title  review_stars  \
# 0  La Police s'inscrit en acheteur privé sur Pric...             5
# 1                     Chef D'Oeuvre Absolu en vue...             5
# 2  Effet garanti sur la terrase. Ils donnent immé...             3
# 3                                        bon produit             4
# 4                                 Apple Power MAC G4             3
#
#                                              product  Target
# 0  2fbb619e3606f9b7c213e858a109cda771aa2c47ce50d5...       0
# 1  7b56d9d378d9e999d293f301ac43d044cd7b4786d09afb...       1
# ...

# %%
# 1. Clean data : remove duplicates and Nall values
df_clean = clean_data(df)

# 2. Add text column to df
df_clean = create_text_column(df_clean, ["review_title","review_content"])

# 3. Clean text in text column
df_clean["text"] = df_clean["text"].astype(str).apply(clean_text)

print("Text column after cleaning process")
print(df_clean["text"].iloc[0:5])

# 4. Convert text column to numerical vectors by TF-IDF
X, y = convert_by_TF_IDF(df_clean)

# 5. Split data to train and test set
X_train, X_test, y_train, y_test = split_data(X, y, test_size=0.2, random_state=42)

print("Train and test shapes : X_train, X_test, y_train, y_test")
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# No duplicate rows found.
# Found 3 missing values. Filling them with 0...
# After filling missing values: 0 missing values remaining
# Text column after cleaning process
# 0    la police s inscrit en acheteur privé sur pric...
# 1    chef d oeuvre absolu en vue alors là on a affa...
# 2    effet garanti sur la terrase ils donnent imméd...
# 3    bon produit tres bon rapport qualite prix tre ...
# 4    apple power mac g ordinateur de bureau trés bi...
# Name: text, dtype: object
# Vocabulary saved successfully!
# Train and test shapes : X_train, X_test, y_train, y_test
# ((48000, 5000), (12000, 5000), (48000,), (12000,))

# %% [markdown]
# ## 3. Model training

# %%
model_lr = logistic_regression_model_training(X_train, y_train, 300)
model_lr
# Out:
# Model saved successfully!
# LogisticRegression(max_iter=300)

# %% [markdown]
# ## 4. Evaluation

# %%
print(eval_lr_model(X_test, y_test, model_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.54      0.58      5327
#            1       0.67      0.76      0.71      6673
#
#     accuracy                           0.66     12000
#    macro avg       0.66      0.65      0.65     12000
# weighted avg       0.66      0.66      0.66     12000
